# %%
import pandas as pd

df = pd.read_csv("../input/bigdatacertificationkr/basic2.csv", parse_dates=['Date'], index_col=0)

df_w = df.resample("W").sum()

sales_max = df_w['Sales'].max()
sales_min = df_w['Sales'].min()

answer = sales_max - sales_min
print(answer)
# Out:
# 91639050
