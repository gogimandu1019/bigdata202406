# %%
import pandas as pd
df = pd.read_csv("../input/bigdatacertificationkr/basic2.csv")
df
df.head()

df.isnull().sum() #uv에 결측치가 있음

#1일 시차가 나는 컬럼 date_previous
df['date_previous'] = df['PV'].shift(1)
df.head()
df['date_previous'] = df['date_previous'].fillna(method = 'bfill')
df.head()

cond =( (df['Events'] == 1) & (df['Sales'] <= 1000000) )
print(df[cond]['date_previous'].sum())
# Out:
# 1894876.0
