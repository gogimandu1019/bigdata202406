# %% [markdown]
# <a href="https://colab.research.google.com/github/gogimandu1019/bigdata202406/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
}
data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# %%
pd.read_csv('data.csv')
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
df = pd.read_csv('data.csv')

# %%
df.head() #앞에서 5개
# Out:
#       메뉴    가격  할인율  칼로리
# 0  아메리카노  4100  0.5   10
# 1   카페라떼  4600  0.1  180
# 2   카페모카  4600  0.2  420
# 3  바닐라라떼  5100  0.3  320
# 4     녹차  4100  0.0   20

# %%
df.tail(3) #뒤에서 n개, 지정 안하면 5개
# Out:
#         메뉴    가격  할인율  칼로리
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
menu = pd.Series(['아아','아라','바콜'])
menu
# Out:
# 0    아아
# 1    아라
# 2    바콜
# dtype: object

# %%
price = pd.Series([2000,3000,4000])
price
# Out:
# 0    2000
# 1    3000
# 2    4000
# dtype: int64

# %%
pd.DataFrame({
    "menu" : menu,
    "price" : price
})
# Out:
#   menu  price
# 0   아아   2000
# 1   아라   3000
# 2   바콜   4000

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
data = {
    "메뉴":['아메리카노','카페라떼','카페모카'],
    "가격":[4100,4600,4600],
    "할인율":[0.5, 0.1, 0.2],
    "칼로리":[10, 180, 420],
}
cafe = pd.DataFrame(data)
cafe
# Out:
#       메뉴    가격  할인율  칼로리
# 0  아메리카노  4100  0.5   10
# 1   카페라떼  4600  0.1  180
# 2   카페모카  4600  0.2  420

# %%
df[['가격','할인율']]
# Out:
#      가격  할인율
# 0  4100  0.5
# 1  4600  0.1
# 2  4600  0.2
# 3  5100  0.3
# 4  4100  0.0
# 5  5000  0.0
# 6  5100  0.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['가격'])
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (7, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   할인율     7 non-null      float64
#  3   칼로리     7 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 352.0+ bytes

# %%
df.describe()
# Out:
#                 가격       할인율         칼로리
# count     7.000000  7.000000    7.000000
# mean   4657.142857  0.157143  264.285714
# std     435.343324  0.190238  196.965068
# min    4100.000000  0.000000   10.000000
# 25%    4350.000000  0.000000  100.000000
# 50%    4600.000000  0.100000  320.000000
# 75%    5050.000000  0.250000  410.000000
# max    5100.000000  0.500000  500.000000

# %%
df.describe(include='O')
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %%
df.corr(numeric_only = True)
# Out:
#            가격       할인율       칼로리
# 가격   1.000000 -0.327738  0.853837
# 할인율 -0.327738  1.000000 -0.390151
# 칼로리  0.853837 -0.390151  1.000000

# %%
# 중복 값이 있는 데이터 생성
car = {
    "car":['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
    "size":['S','M','S','S','M','M','L','S','S', 'M','S']
}
car = pd.DataFrame(car)
car.head(3)
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S

# %%
car.nunique() #항목 종류
# Out:
# car     2
# size    3
# dtype: int64

# %%
car['car'].unique()
# Out:
# array(['Sedan', 'SUV'], dtype=object)

# %%
car['car'].value_counts() #항목별로갯수확인
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64

# %%
car['size'].value_counts()
# Out:
# size
# S    6
# M    4
# L    1
# Name: count, dtype: int64

# %%
# 데이터 프레임 만들기 (할인율과 칼로리 -> 문자열)
data = {
    "메뉴":['아메리카노', '카페라떼', '카페모카', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100],
    "할인율":['0.5', '0.1', '0.2', '0.3'],
    "칼로리":[10,180,420,320],
}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      4 non-null      object
#  1   가격      4 non-null      int64
#  2   할인율     4 non-null      object
#  3   칼로리     4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df['할인율'] = df['할인율'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      4 non-null      object
#  1   가격      4 non-null      int64
#  2   할인율     4 non-null      float64
#  3   칼로리     4 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 256.0+ bytes

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3  바닐라콜드브루  5100  0.3  320

# %%
df['new'] = 0
df
# Out:
#         메뉴    가격  할인율  칼로리  new
# 0    아메리카노  4100  0.5   10    0
# 1     카페라떼  4600  0.1  180    0
# 2     카페모카  4600  0.2  420    0
# 3  바닐라콜드브루  5100  0.3  320    0

# %%
df['할인가'] = df['가격'] * (1- df['할인율'])
df
# Out:
#         메뉴    가격  할인율  칼로리  new     할인가
# 0    아메리카노  4100  0.5   10    0  2050.0
# 1     카페라떼  4600  0.1  180    0  4140.0
# 2     카페모카  4600  0.2  420    0  3680.0
# 3  바닐라콜드브루  5100  0.3  320    0  3570.0

# %%
#결측값 컬럼 추가
import numpy as np
df['원두'] = np.nan
df
# Out:
#         메뉴    가격  할인율  칼로리  new     할인가  원두
# 0    아메리카노  4100  0.5   10    0  2050.0 NaN
# 1     카페라떼  4600  0.1  180    0  4140.0 NaN
# 2     카페모카  4600  0.2  420    0  3680.0 NaN
# 3  바닐라콜드브루  5100  0.3  320    0  3570.0 NaN

# %%
df = df.drop('new', axis = 1)
df
# Out:
#         메뉴    가격  할인율  칼로리     할인가  원두
# 0    아메리카노  4100  0.5   10  2050.0 NaN
# 1     카페라떼  4600  0.1  180  4140.0 NaN
# 2     카페모카  4600  0.2  420  3680.0 NaN
# 3  바닐라콜드브루  5100  0.3  320  3570.0 NaN

# %%
df = df.drop(0, axis = 0)
df
# Out:
#         메뉴    가격  할인율  칼로리     할인가  원두
# 1     카페라떼  4600  0.1  180  4140.0 NaN
# 2     카페모카  4600  0.2  420  3680.0 NaN
# 3  바닐라콜드브루  5100  0.3  320  3570.0 NaN

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3  바닐라콜드브루  5100  0.3  320

# %%
df.to_csv('data2.csv')

# %%
new_df = pd.read_csv('data2.csv')
new_df.head()
# Out:
#    Unnamed: 0       메뉴    가격  할인율  칼로리
# 0           0    아메리카노  4100  0.5   10
# 1           1     카페라떼  4600  0.1  180
# 2           2     카페모카  4600  0.2  420
# 3           3  바닐라콜드브루  5100  0.3  320

# %%
# 데이터 프레임 만들기 (할인율과 칼로리 -> 문자열)
data = {
    "메뉴":['아메리카노', '카페라떼', '카페모카', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100],
    "할인율":['0.5', '0.1', '0.2', '0.3'],
    "칼로리":[10,180,420,320],
}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      4 non-null      object
#  1   가격      4 non-null      int64
#  2   할인율     4 non-null      object
#  3   칼로리     4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df['이벤트가'] = df['가격'] * 0.5
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  2050.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420  코스타리카  2300.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2550.0
# 4       녹차  4100  0.0   20  코스타리카  2050.0
# 5     초코라떼  5000  0.0  500  코스타리카  2500.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  2550.0
# 7    에소프레소  2000  NaN   10  코스타리카  1000.0

# %%
df['할인율'] = df['할인율'].astype('float')
df['할인가'] = df['가격'] * (1 - df['할인율'])
df
# Out:
#         메뉴    가격  할인율  칼로리    이벤트가     할인가
# 0    아메리카노  4100  0.5   10  2050.0  2050.0
# 1     카페라떼  4600  0.1  180  2300.0  4140.0
# 2     카페모카  4600  0.2  420  2300.0  3680.0
# 3  바닐라콜드브루  5100  0.3  320  2550.0  3570.0

# %%
df = df.drop('칼로리', axis = 1)

# %%
df
# Out:
#         메뉴    가격  할인율    이벤트가     할인가
# 0    아메리카노  4100  0.5  2050.0  2050.0
# 1     카페라떼  4600  0.1  2300.0  4140.0
# 2     카페모카  4600  0.2  2300.0  3680.0
# 3  바닐라콜드브루  5100  0.3  2550.0  3570.0

# %%
df.loc[1] #loc[인덱스명]
# Out:
# 메뉴        카페라떼
# 가격        4600
# 할인율        0.1
# 이벤트가    2300.0
# 할인가     4140.0
# Name: 1, dtype: object

# %%
df.iloc[1] #iloc[인덱스번호]
# Out:
# 메뉴        카페라떼
# 가격        4600
# 할인율        0.1
# 이벤트가    2300.0
# 할인가     4140.0
# Name: 1, dtype: object

# %%
df.loc[ : , '가격']
# Out:
# 0    4100
# 1    4600
# 2    4600
# 3    5100
# Name: 가격, dtype: int64

# %%
df.iloc[ : , 1]
# Out:
# 0    4100
# 1    4600
# 2    4600
# 3    5100
# Name: 가격, dtype: int64

# %%
df.loc[1:2, '가격':'칼로리']
# Out:
#      가격  할인율  칼로리
# 1  4600  0.1  180
# 2  4600  0.2  420

# %%
df.iloc[1:3, 1:]
# Out:
#      가격  할인율  칼로리
# 1  4600  0.1  180
# 2  4600  0.2  420

# %%
# 학습 전 실행: csv파일 (data.csv) 생성
import pandas as pd
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
}
data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# %%
df = pd.read_csv('data.csv')
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4100
# 할인율      0.5
# 칼로리       10
# Name: 0, dtype: object

# %%
df.loc[:, "가격"]
# Out:
# 0    4100
# 1    4600
# 2    4600
# 3    5100
# 4    4100
# 5    5000
# 6    5100
# Name: 가격, dtype: int64

# %%
df.loc[1,'가격']
# Out:
# 4600

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
df.loc[2,'메뉴':'가격']
# Out:
# 메뉴    카페모카
# 가격    4600
# Name: 2, dtype: object

# %%
df.loc[2, ['메뉴','칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     420
# Name: 2, dtype: object

# %%
df.loc[1:2, '메뉴':'가격']
# Out:
#      메뉴    가격
# 1  카페라떼  4600
# 2  카페모카  4600

# %%
df.head()
# Out:
#       메뉴    가격  할인율  칼로리
# 0  아메리카노  4100  0.5   10
# 1   카페라떼  4600  0.1  180
# 2   카페모카  4600  0.2  420
# 3  바닐라라떼  5100  0.3  320
# 4     녹차  4100  0.0   20

# %%
df.iloc[0]
# Out:
# 메뉴     아메리카노
# 가격      4100
# 할인율      0.5
# 칼로리       10
# Name: 0, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0    4100
# 1    4600
# 2    4600
# 3    5100
# 4    4100
# 5    5000
# 6    5100
# Name: 가격, dtype: int64

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
df.iloc[2,0:2]
# Out:
# 메뉴    카페모카
# 가격    4600
# Name: 2, dtype: object

# %%
df.iloc[1:3]
# Out:
#      메뉴    가격  할인율  칼로리
# 1  카페라떼  4600  0.1  180
# 2  카페모카  4600  0.2  420

# %%
import numpy as np

df['원두'] = np.nan
df
# Out:
#         메뉴    가격  할인율  칼로리  원두
# 0    아메리카노  4100  0.5   10 NaN
# 1     카페라떼  4600  0.1  180 NaN
# 2     카페모카  4600  0.2  420 NaN
# 3    바닐라라떼  5100  0.3  320 NaN
# 4       녹차  4100  0.0   20 NaN
# 5     초코라떼  5000  0.0  500 NaN
# 6  바닐라콜드브루  5100  0.0  400 NaN

# %%
df.loc[0,'원두'] = '콜롬비아'
df
# Out:
#         메뉴    가격  할인율  칼로리    원두
# 0    아메리카노  4100  0.5   10  콜롬비아
# 1     카페라떼  4600  0.1  180   NaN
# 2     카페모카  4600  0.2  420   NaN
# 3    바닐라라떼  5100  0.3  320   NaN
# 4       녹차  4100  0.0   20   NaN
# 5     초코라떼  5000  0.0  500   NaN
# 6  바닐라콜드브루  5100  0.0  400   NaN

# %%
df.loc['시즌'] = ['크리스마스라떼',6000,0,500,'한국']

# %%
df
# Out:
#          메뉴    가격  할인율  칼로리   원두
# 0     아메리카노  4100  0.5   10  NaN
# 1      카페라떼  4600  0.1  180  NaN
# 2      카페모카  4600  0.2  420  NaN
# 3     바닐라라떼  5100  0.3  320  NaN
# 4        녹차  4100  0.0   20  NaN
# 5      초코라떼  5000  0.0  500  NaN
# 6   바닐라콜드브루  5100  0.0  400  NaN
# 시즌  크리스마스라떼  6000  0.0  500   한국

# %%
df.loc[7] = {'메뉴' : '에소프레소', '가격' : 2000, '칼로리' : 10}
df
# Out:
#         메뉴    가격  할인율  칼로리    원두
# 0    아메리카노  4100  0.5   10  콜롬비아
# 1     카페라떼  4600  0.1  180   NaN
# 2     카페모카  4600  0.2  420   NaN
# 3    바닐라라떼  5100  0.3  320   NaN
# 4       녹차  4100  0.0   20   NaN
# 5     초코라떼  5000  0.0  500   NaN
# 6  바닐라콜드브루  5100  0.0  400   NaN
# 7    에소프레소  2000  NaN   10   NaN

# %%
df = df.drop('시즌', axis = 0)
df
# Out:
#         메뉴    가격  할인율  칼로리   원두
# 0    아메리카노  4100  0.5   10  NaN
# 1     카페라떼  4600  0.1  180  NaN
# 2     카페모카  4600  0.2  420  NaN
# 3    바닐라라떼  5100  0.3  320  NaN
# 4       녹차  4100  0.0   20  NaN
# 5     초코라떼  5000  0.0  500  NaN
# 6  바닐라콜드브루  5100  0.0  400  NaN
# 7    에소프레소  2000  NaN   10  NaN

# %%
df.sort_index(ascending=False)
# Out:
#         메뉴    가격  할인율  칼로리   원두
# 7    에소프레소  2000  NaN   10  NaN
# 6  바닐라콜드브루  5100  0.0  400  NaN
# 5     초코라떼  5000  0.0  500  NaN
# 4       녹차  4100  0.0   20  NaN
# 3    바닐라라떼  5100  0.3  320  NaN
# 2     카페모카  4600  0.2  420  NaN
# 1     카페라떼  4600  0.1  180  NaN
# 0    아메리카노  4100  0.5   10  NaN

# %%
df.sort_values('메뉴', ascending = False)
# Out:
#         메뉴    가격  할인율  칼로리   원두
# 2     카페모카  4600  0.2  420  NaN
# 1     카페라떼  4600  0.1  180  NaN
# 5     초코라떼  5000  0.0  500  NaN
# 7    에소프레소  2000  NaN   10  NaN
# 0    아메리카노  4100  0.5   10  NaN
# 6  바닐라콜드브루  5100  0.0  400  NaN
# 3    바닐라라떼  5100  0.3  320  NaN
# 4       녹차  4100  0.0   20  NaN

# %%
df = df.sort_values(['가격','메뉴'], ascending = [False, True])
df
# Out:
#         메뉴    가격  할인율  칼로리   원두
# 3    바닐라라떼  5100  0.3  320  NaN
# 6  바닐라콜드브루  5100  0.0  400  NaN
# 5     초코라떼  5000  0.0  500  NaN
# 1     카페라떼  4600  0.1  180  NaN
# 2     카페모카  4600  0.2  420  NaN
# 4       녹차  4100  0.0   20  NaN
# 0    아메리카노  4100  0.5   10  NaN
# 7    에소프레소  2000  NaN   10  NaN

# %%
df.reset_index(drop=True)
# Out:
#         메뉴    가격  할인율  칼로리    원두
# 0    아메리카노  4100  0.5   10  콜롬비아
# 1     카페라떼  4600  0.1  180   NaN
# 2     카페모카  4600  0.2  420   NaN
# 3    바닐라라떼  5100  0.3  320   NaN
# 4       녹차  4100  0.0   20   NaN
# 5     초코라떼  5000  0.0  500   NaN
# 6  바닐라콜드브루  5100  0.0  400   NaN
# 7    에소프레소  2000  NaN   10   NaN

# %%
# 데이터 프레임 만들기
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3],
    "칼로리":[10,180,420,320],
}
df = pd.DataFrame(data)
df.head()
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3  바닐라콜드브루  5100  0.3  320

# %%
df.loc[:2]
# Out:
#       메뉴    가격  할인율  칼로리
# 0  아메리카노  4100  0.5   10
# 1   카페라떼  4600  0.1  180
# 2   카페모카  4600  0.2  420

# %%
#df.loc[1:2, '메뉴':'할인율']
df.iloc[1:3, :3]
# Out:
#      메뉴    가격  할인율
# 1  카페라떼  4600  0.1
# 2  카페모카  4600  0.2

# %%
import pandas as pd
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
df = df.sort_values(by='가격', ascending=False)
df.iloc[:3]
# Out:
#         메뉴    가격  할인율  칼로리  원두    이벤트가     할인가
# 3    바닐라라떼  5100  0.3  320 NaN  2550.0  3570.0
# 6  바닐라콜드브루  5100  0.0  400 NaN  2550.0  5100.0
# 5     초코라떼  5000  0.0  500 NaN  2500.0  5000.0

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3    바닐라라떼  5100  0.3  320
# 4       녹차  4100  0.0   20
# 5     초코라떼  5000  0.0  500
# 6  바닐라콜드브루  5100  0.0  400

# %%
cond = df['할인율'] > 0.2
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리  원두    이벤트가     할인가
# 3  바닐라라떼  5100  0.3  320 NaN  2550.0  3570.0
# 0  아메리카노  4100  0.5   10 NaN  2050.0  2050.0

# %%
df.isnull().sum()
# Out:
# 메뉴      0
# 가격      0
# 할인율     1
# 칼로리     0
# 원두      8
# 이벤트가    1
# 할인가     1
# dtype: int64

# %%
df['원두'] = df['원두'].fillna('코스타리카')

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리     원두
# 0    아메리카노  4100  0.5   10   콜롬비아
# 1     카페라떼  4600  0.1  180  코스타리카
# 2     카페모카  4600  0.2  420  코스타리카
# 3    바닐라라떼  5100  0.3  320  코스타리카
# 4       녹차  4100  0.0   20  코스타리카
# 5     초코라떼  5000  0.0  500  코스타리카
# 6  바닐라콜드브루  5100  0.0  400  코스타리카
# 7    에소프레소  2000  NaN   10  코스타리카

# %%
df['이벤트가'] = df['이벤트가'].fillna(1900)

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  2050.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420  코스타리카  2300.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2550.0
# 4       녹차  4100  0.0   20  코스타리카  2050.0
# 5     초코라떼  5000  0.0  500  코스타리카  2500.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  2550.0
# 7    에소프레소  2000  NaN   10  코스타리카  1000.0

# %%
# 학습 전 실행: csv파일 (data.csv) 생성
import pandas as pd
import numpy as np
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
    "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}
data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# %%
# 데이터 불러오기
df = pd.read_csv("data.csv")
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
df['이벤트가'] = df['이벤트가'].fillna(1900)

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
df['원두'] = df['원두'].fillna('코스타리카')

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
df = df.replace('아메리카노','룽고').replace('녹차','그린티')

# %%
d = {'아메리카노':'룽고','녹차':'그린티'}
df.replace(d)
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4      그린티  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
df = df.replace(1900,1500)

# %%
df.loc[3, '원두'] = '과테말라'
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1500.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1500.0
# 3    바닐라라떼  5100  0.3  320   과테말라  2600.0
# 4      그린티  4100  0.0   20     한국  1500.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 데이터 불러오기
df = pd.read_csv('data.csv')
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
df.count()
# Out:
# 메뉴      7
# 가격      7
# 할인율     7
# 칼로리     7
# 원두      4
# 이벤트가    5
# dtype: int64

# %%
df.count(axis=1)
# Out:
# 0    6
# 1    5
# 2    5
# 3    5
# 4    5
# 5    6
# 6    5
# dtype: int64

# %%
len(df)
# Out:
# 7

# %%
df.shape[0]
# Out:
# 7

# %%
df['가격'].max()
# Out:
# 5100

# %%
df['가격'].min()
# Out:
# 4100

# %%
df['가격'].mean()
# Out:
# 4657.142857142857

# %%
df['가격'].median()
# Out:
# 4600.0

# %%
df['가격'].std()
# Out:
# 435.3433237386437

# %%
df['가격'].var()
# Out:
# 189523.8095238095

# %%
df['가격'].skew()
# Out:
# -0.3739900475641664

# %%
df['가격'].kurt()
# Out:
# -1.7170778515694067

# %%
df['가격'].describe()
# Out:
# count       7.000000
# mean     4657.142857
# std       435.343324
# min      4100.000000
# 25%      4350.000000
# 50%      4600.000000
# 75%      5050.000000
# max      5100.000000
# Name: 가격, dtype: float64

# %%
df['가격'].quantile(0.25)
# Out:
# 4350.0

# %%
df['가격'].quantile(0.75)
# Out:
# 5050.0

# %%
cond = df['가격'].quantile(0.75) < df['가격']
df[cond]
# Out:
#         메뉴    가격  할인율  칼로리   원두    이벤트가
# 3    바닐라라떼  5100  0.3  320  NaN  2600.0
# 6  바닐라콜드브루  5100  0.0  400  NaN  3200.0

# %%
type(df['원두'].mode()[0])
# Out:
# str

# %%
def cal(x):
  if x >= 300:
    return "no"
  else:
    return "yes"

df['먹어도될까요'] = df['칼로리'].apply(cal)

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가 먹어도될까요
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0    yes
# 1     카페라떼  4600  0.1  180   NaN  2300.0    yes
# 2     카페모카  4600  0.2  420  과테말라     NaN     no
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0     no
# 4       녹차  4100  0.0   20    한국     NaN    yes
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0     no
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0     no

# %%
df.groupby('원두').mean(numeric_only=True)
# Out:
#           가격   할인율    칼로리    이벤트가
# 원두
# 과테말라  4600.0  0.20  420.0     NaN
# 콜롬비아  4550.0  0.25  255.0  2450.0
# 한국    4100.0  0.00   20.0     NaN

# %%
df.groupby(['원두','할인율']).mean(numeric_only=True)
# Out:
#               가격    칼로리    이벤트가
# 원두   할인율
# 과테말라 0.2  4600.0  420.0     NaN
# 콜롬비아 0.0  5000.0  500.0  3000.0
#      0.5  4100.0   10.0  1900.0
# 한국   0.0  4100.0   20.0     NaN

# %%
df.groupby(['원두','할인율'])['가격'].mean(numeric_only=True)
# Out:
# 원두    할인율
# 과테말라  0.2    4600.0
# 콜롬비아  0.0    5000.0
#       0.5    4100.0
# 한국    0.0    4100.0
# Name: 가격, dtype: float64

# %%
pd.DataFrame(df.groupby(['원두','할인율'])['가격'].mean(numeric_only=True))
# Out:
#               가격
# 원두   할인율
# 과테말라 0.2  4600.0
# 콜롬비아 0.0  5000.0
#      0.5  4100.0
# 한국   0.0  4100.0

# %%
df.groupby(['원두','할인율']).mean(numeric_only=True).reset_index()
# Out:
#      원두  할인율      가격    칼로리    이벤트가
# 0  과테말라  0.2  4600.0  420.0     NaN
# 1  콜롬비아  0.0  5000.0  500.0  3000.0
# 2  콜롬비아  0.5  4100.0   10.0  1900.0
# 3    한국  0.0  4100.0   20.0     NaN

# %%
# 데이터 불러오기
df = pd.read_csv('data.csv')
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
min_price = df['이벤트가'].min()
df['이벤트가'] = df['이벤트가'].fillna(min_price)
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
f = df['원두'].mode()[0]
df['원두'] = df['원두'].fillna(f)
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  콜롬비아  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  콜롬비아  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  콜롬비아  3200.0

# %%
cond = df['가격'] >= 5000
len(df[cond])
# Out:
# 3
